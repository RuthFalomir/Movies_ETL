# %%
import pandas as pd
import json

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory = False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 17630  False                   NaN      0
# 17824  False                   NaN      0
# 36738  False                   NaN      0
# 45079  False                   NaN      0
# 25540  False                   NaN      0
#
#                                                   genres  \
# 17630  [{'id': 10752, 'name': 'War'}, {'id': 18, 'nam...
# 17824  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 36738                [{'id': 99, 'name': 'Documentary'}]
# 45079                [{'id': 99, 'name': 'Documentary'}]
# 25540  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                      homepage      id    imdb_id original_language  \
# 17630                     NaN   31398  tt0066078                en
# 17824                     NaN   74525  tt0040798                en
# 36738                     NaN  343825  tt0200698                en
# 45079  http://www.obitdoc.com  390747  tt4820284                en
# 25540                     NaN  293380  tt0077977                en
#
#                       original_title  \
# 17630                 Mihai Viteazul
# 17824                 Sleep, My Love
# 36738  Het is een schone dag geweest
# 45079                           Obit
# 25540                   The Nativity
#
#                                                 overview  ... release_date  \
# 17630  An epic fresco depicting the reign (1593-1601)...  ...   1970-01-01
# 17824  A woman wakes up in the middle of the night on...  ...   1948-02-18
# 36738  Documentary about the last four seasons on the...  ...   1993-11-04
# 45079  How do you put a life into 500 words? Ask the ...  ...   2017-04-26
# 25540  The story of the courtship of Joseph and Mary,...  ...   1978-12-17
#
#       revenue runtime                          spoken_languages    status  \
# 17630     0.0   107.0   [{'iso_639_1': 'ro', 'name': 'Română'}]  Released
# 17824     0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 36738     0.0    70.0                                        []  Released
# 45079     0.0    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 25540     0.0    98.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 17630                                                NaN
# 17824  ...the most terrifying words a man ever whispe...
# 36738                                                NaN
# 45079  An inside look at life on the New York Times o...
# 25540                                                NaN
#
#                                title  video vote_average vote_count
# 17630              Michael the Brave  False          8.2        9.0
# 17824                 Sleep, My Love  False          5.7       11.0
# 36738  Het is een schone dag geweest  False          0.0        0.0
# 45079                           Obit  False          5.3        3.0
# 25540                   The Nativity  False          0.0        0.0
#
# [5 rows x 24 columns]
